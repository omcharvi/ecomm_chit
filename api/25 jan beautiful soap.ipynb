# %%
from bs4 import BeautifulSoup

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bs4 import BeautifulSoup

# %%
sample_data= """<html><head><title>this is my sample html page</title></head>
<body><h1><this is my first heading</h1>
<h1><this is my first heading</h1>
h1><this is my first heading</h1>
h1><this is my first heading</h1>
h1><this is my first heading</h1>
<h2><this is my first heading</h2>
<h3><this is my first heading</h3>
<h4><this is my first heading</h4>
<h5><this is my first heading</h5>
<h6><this is my first heading</h6>
<h7><this is my first heading</h7><p>my name is chitranjan kumar</p></body>
/html>"""

# %%
data_parse= BeautifulSoup(sample_data, 'html.parser')

# %%
data_parse
# Out:
# <html><head><title>this is my sample html page</title></head>
# <body><h1><this first="" h1="" heading<="" is="" my="">
# <h1><this first="" h1="" heading<="" is="" my="">
# h1&gt;<this first="" h1="" heading<="" is="" my="">
# h1&gt;<this first="" h1="" heading<="" is="" my="">
# h1&gt;<this first="" h1="" heading<="" is="" my="">
# <h2><this first="" h2="" heading<="" is="" my="">
# <h3><this first="" h3="" heading<="" is="" my="">
# <h4><this first="" h4="" heading<="" is="" my="">
# <h5><this first="" h5="" heading<="" is="" my="">
# <h6><this first="" h6="" heading<="" is="" my="">
# <h7><this first="" h7="" heading<="" is="" my=""><p>my name is chitranjan kumar</p></this></h7></this></h6></this></h5></this></h4></this></h3></this></h2></this></this></this></this></h1></this></h1></body>
# /html&gt;</html>

# %%
data_parse.h1
# Out:
# <h1><this first="" h1="" heading<="" is="" my="">
# <h1><this first="" h1="" heading<="" is="" my="">
# h1&gt;<this first="" h1="" heading<="" is="" my="">
# h1&gt;<this first="" h1="" heading<="" is="" my="">
# h1&gt;<this first="" h1="" heading<="" is="" my="">
# <h2><this first="" h2="" heading<="" is="" my="">
# <h3><this first="" h3="" heading<="" is="" my="">
# <h4><this first="" h4="" heading<="" is="" my="">
# <h5><this first="" h5="" heading<="" is="" my="">
# <h6><this first="" h6="" heading<="" is="" my="">
# <h7><this first="" h7="" heading<="" is="" my=""><p>my name is chitranjan kumar</p></this></h7></this></h6></this></h5></this></h4></this></h3></this></h2></this></this></this></this></h1></this></h1>

# %%
data_parse.h3
# Out:
# <h3><this first="" h3="" heading<="" is="" my="">
# <h4><this first="" h4="" heading<="" is="" my="">
# <h5><this first="" h5="" heading<="" is="" my="">
# <h6><this first="" h6="" heading<="" is="" my="">
# <h7><this first="" h7="" heading<="" is="" my=""><p>my name is chitranjan kumar</p></this></h7></this></h6></this></h5></this></h4></this></h3>

# %%
data_parse.p.string
# Out:
# 'my name is chitranjan kumar'

# %%
for i in data_parse.find_all('h1'):
    print (i.string)
# Out:
# None
# None

# %%
data= """<img src="chit.jpg" >"""
img_data= BeautifulSoup(data, 'html.parser')

# %%
img_data.img['src']
# Out:
# 'chit.jpg'

# %%
import requests

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %%
nba_data = requests.get("https://www.sportingnews.com/in/nba?gr=www")

# %%
nba_data.text
# Out:
# '\n\n\n\n<!DOCTYPE html>\n<html lang="en-in" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">\n\n<head>\n    <!-- New-World: Yes -->\n    <!-- Version: d4b01f0a54005ed48fcbb7f20f8a4720559fd3fd -->\n    <!-- New Templates: Yes -->\n    <!-- OneTrust Cookies Consent Notice start -->\r\n<script src="https://cdn-ukwest.onetrust.com/scripttemplates/otSDKStub.js" type="text/javascript" charset="UTF-8" data-domain-script="e11b4f1e-9f63-4748-96f7-f759c0d78621"></script>\r\n<!-- OneTrust Cookies Consent Notice end -->\n\n    <meta charset="utf-8">\n\n<meta property="fb:app_id" content="117854138246106" />\n<meta property="og:type" content="website" />\n<meta prope
# ...

# %%
nba_html =  BeautifulSoup(nba_data.text,'html.parser')

# %%
nba_html
# Out:
# NBA.com India | The official site of the NBA | Sporting News India
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Skip to main content
#
#
#
#
#
#
# Your default site has been set for 7 days
#
#
#
#
#
#
# SET DEFAULT EDITION?
# NBA US
#
#
#
#
#
#
#
#
# NBA.com
#
#
# Teams
#
#
# Global
#
#
# Set default edition
#
#
#
#
#
# Atlanta
#
#
# Boston
#
#
# Brooklyn
#
#
# Charlotte
#
#
# Chicago
#
#
# Cleveland
#
#
# Dallas
#
#
# Denver
#
#
# Detroit
#
#
# Golden State
#
#
# Houston
#
#
# Indiana
#
#
# LA Clippers
#
#
# LA Lakers
#
#
# Memphis
#
#
# Miami
#
#
# Milwaukee
#
#
# Minnesota
#
#
# New Orleans
#
#
# New York
#
#
# Oklahoma City
#
#
# Orlando
#
#
# Philadelphia
#
#
# Phoenix
#
#
# Portland
#
#
# Sacramento
#
#
# San Antonio
#
#
# Toronto
#
#
# Utah
#
#
# Washington
#
#
#
#
#
#
# Argentina
#
#
# Australia
#
#
# Canada
#
#
# 中国
#
#
# España
#
#
# France
#
#
# 日本
#
#
# India
#
#
# Israel
#
#
# Italia
#
#
# MENA
#
#
# Mexico
#
#
# Thailand
#
#
# ...

# %%
print(nba_html.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-in" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <!-- New-World: Yes -->
#   <!-- Version: d4b01f0a54005ed48fcbb7f20f8a4720559fd3fd -->
#   <!-- New Templates: Yes -->
#   <!-- OneTrust Cookies Consent Notice start -->
#   <script charset="UTF-8" data-domain-script="e11b4f1e-9f63-4748-96f7-f759c0d78621" src="https://cdn-ukwest.onetrust.com/scripttemplates/otSDKStub.js" type="text/javascript">
#   </script>
#   <!-- OneTrust Cookies Consent Notice end -->
#   <meta charset="utf-8"/>
#   <meta content="117854138246106" property="fb:app_id">
#    <meta content="website" property="og:type"/>
# ...

# %%
nba_html.title.string
# Out:
# 'NBA.com India | The official site of the NBA | Sporting News India'

# %%
nba_data.h1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 nba_data.h1
#
# AttributeError: 'Response' object has no attribute 'h1'

# %%
nba_html.img['src']
# Out:
# 'https://static-nw-production.sportingnews.com/media/filer_public/c0/8d/c08daa9c-b562-4743-881b-71e57ce0e717/menu-item-logoscricketsports_cricket_3x_84184512-d8de-4311-a8bc-1687e3046e2e.webp.48x48_q85_crop.webp'

# %%
nba_html.img['alt']
# Out:
# 'Cricket Logo'

# %%
requests.get('https://www.devnetjobsindia.org/')
# Out:
# <Response [200]>

# %%
dev_data = requests.get('https://www.devnetjobsindia.org/')

# %%
dev_html = BeautifulSoup(dev_data.text, 'html.parser')

# %%
dev_html
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <!-- Meta Tags -->
# ...

# %%
dev_html.title.string
# Out:
# '\r\n\t\r\n        International Development, Jobs, NGOs, Consulting, UN, UNDP, World Bank, International\r\n        Development Community, IFC, Environment, Trade, Charity, Non-Profits, UNESCO, UNAIDS,\r\n        WHO, USAID, Careers, IFAD, Consultancies\r\n    \r\n'

# %%
dev_html.h1.string

# %%
dev_html.img['src']
# Out:
# 'images/DevNetIndia_Logo.png'

# %%
dev_html.p
# Out:
# <p class="text-limeyellow m-0">Jobseekers: <a class="text-limeyellow" href="canlogin.aspx">Login</a> | <a class="text-limeyellow" href="jobseekerregistration.aspx">Register</a></p>

# %%
dev_html.p.string

# %%
pip install datetime
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -------------------------- ------------- 0.8/1.2 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 3.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from datetime import datetime

# %%
print(datetime.now())
# Out:
# 2025-07-01 00:46:37.329947

# %%
date_time = datetime.now()

# %%
date_time.date()
# Out:
# datetime.date(2025, 7, 1)

# %%
print(date_time.time())
# Out:
# 00:47:11.034514

# %%
date_time.year
# Out:
# 2025

# %%
date_time.month
# Out:
# 7

# %%
date_time.day
# Out:
# 1

# %%
date_time.hour
# Out:
# 0

# %%
print(date_time.minute)
# Out:
# 47

# %%
pip install pytz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pytz

# %%
utc_standard_time = datetime.now(pytz.utc)

# %%
print(utc_standard_time)
# Out:
# 2025-06-30 19:25:41.196219+00:00

# %%
indian_std = pytz.timezone('asia/kolkata')

# %%
print(utc_standard_time.astimezone(indian_std))
# Out:
# 2025-07-01 00:55:41.196219+05:30
